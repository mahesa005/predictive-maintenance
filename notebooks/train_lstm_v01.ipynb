# %% [markdown]
# # 🔧 Predictive Maintenance: LSTM Model Training
#
# **Pipeline Overview:**
# 1. **EDA** - Exploratory Data Analysis
# 2. **Preprocessing** - Data Cleaning & Feature Engineering
# 3. **SMOTE** - Handle Class Imbalance
# 4. **Sequence Creation** - Prepare data for LSTM
# 5. **Model Training** - Train LSTM with validation
# 6. **Evaluation** - Performance metrics & visualization

# %% [markdown]
# ---
# # Part 1: Setup & Imports

# %%
import numpy as np
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE

# Set style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

# Paths
DATA_DIR = os.path.join(os.getcwd(), '..', 'data')
RAW_FILE = os.path.join(DATA_DIR, 'labeled_dataset.csv')
PROCESSED_FILE = os.path.join(DATA_DIR, 'processed_dataset.csv')
PREPROCESSED_DIR = os.path.join(DATA_DIR, 'preprocessed')

print(f"Data directory: {DATA_DIR}")
# Out:
# Data directory: c:\Users\Mahesa\OneDrive\ITB\Coding\Work\Infomedia\predictive-maintenance\notebooks\..\data

# %% [markdown]
# ---
# # Part 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 2.1 Load Raw Data

# %%
df_raw = pd.read_csv(RAW_FILE)
print(f"Dataset Shape: {df_raw.shape}")
print(f"Total Records: {len(df_raw):,}")
df_raw.head()
# Out:
# Dataset Shape: (39259, 11)
# Total Records: 39,259
#      NO            Timestamp Service Type            Service Name  \
# 0  2045  2024-01-01 08:13:45      Inbound  Inbound Contact Center
# 1  2566  2024-01-10 15:06:49            -                       -
# 2  2268  2024-01-05 06:11:00            -                       -
# 3  2560  2024-01-10 14:19:44            -                       -
# 4  2558  2024-01-10 14:02:29   Sosiomedio              Sosiomedio
#
#           Type  Status  SLA (minutes)        Resolved Time  \
# 0  Restoration  Closed           45.0  2024-01-01 08:48:06
# 1  Restoration  Closed           90.0  2024-01-11 16:10:11
# 2  Restoration  Closed          210.0  2024-01-05 06:54:47
# 3  Restoration  Closed          210.0  2024-01-10 16:13:57
# 4  Restoration  Closed          210.0  2024-01-10 16:14:56
#
#   Resolved Duration (minutes) Month  label
# 0                       33,12   Jan      1
# 1                       12,33   Jan      1
# 2                       34,30   Jan      0
# 3                       15,73   Jan      0
# 4                       26,33   Jan      0

# %% [markdown]
# ## 2.2 Data Overview

# %%
print("=" * 60)
print("DATA INFO")
print("=" * 60)
df_raw.info()
# Out:
# ============================================================
# DATA INFO
# ============================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39259 entries, 0 to 39258
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NO                           39259 non-null  int64
#  1   Timestamp                    39259 non-null  object
#  2   Service Type                 37747 non-null  object
#  3   Service Name                 37860 non-null  object
#  4   Type                         39259 non-null  object
#  5   Status                       39259 non-null  object
#  6   SLA (minutes)                33679 non-null  float64
#  7   Resolved Time                39259 non-null  object
#  8   Resolved Duration (minutes)  39259 non-null  object
#  9   Month                        39259 non-null  object
#  10  label                        39259 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 3.3+ MB

# %%
print("=" * 60)
print("STATISTICAL SUMMARY")
print("=" * 60)
df_raw.describe()
# Out:
# ============================================================
# STATISTICAL SUMMARY
# ============================================================
#                  NO  SLA (minutes)         label
# count  39259.000000   33679.000000  39259.000000
# mean    6168.979572   10237.591645      0.311648
# std     6035.868481   22200.551910      0.463173
# min        1.000000       0.000000      0.000000
# 25%     1640.000000     180.000000      0.000000
# 50%     3308.000000     210.000000      0.000000
# 75%    10404.500000    4320.000000      1.000000
# max    20729.000000   86400.000000      1.000000

# %% [markdown]
# ## 2.3 Missing Values Analysis

# %%
missing = df_raw.isnull().sum()
missing_pct = (missing / len(df_raw) * 100).round(2)

missing_df = pd.DataFrame({
    'Column': missing.index,
    'Missing Count': missing.values,
    'Missing %': missing_pct.values
}).sort_values('Missing Count', ascending=False)

print("Missing Values Summary:")
display(missing_df[missing_df['Missing Count'] > 0])

# Visualize
fig, ax = plt.subplots(figsize=(10, 4))
cols_with_missing = missing_df[missing_df['Missing Count'] > 0]['Column'].values
if len(cols_with_missing) > 0:
    sns.barplot(data=missing_df[missing_df['Missing Count'] > 0], 
                x='Column', y='Missing %', ax=ax, palette='Reds_r')
    ax.set_title('Missing Values by Column', fontsize=14)
    ax.set_xlabel('')
    ax.tick_params(axis='x', rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("✅ No missing values!")
# Out:
# Missing Values Summary:
#           Column  Missing Count  Missing %
# 6  SLA (minutes)           5580      14.21
# 2   Service Type           1512       3.85
# 3   Service Name           1399       3.56
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\1418851969.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=missing_df[missing_df['Missing Count'] > 0],

# %% [markdown]
# ## 2.4 Target Variable Distribution (Class Imbalance)

# %%
label_counts = df_raw['label'].value_counts()
label_pct = df_raw['label'].value_counts(normalize=True) * 100

print("Target Variable Distribution:")
print(f"  Class 0 (No Failure): {label_counts[0]:,} ({label_pct[0]:.2f}%)")
print(f"  Class 1 (Failure):    {label_counts[1]:,} ({label_pct[1]:.2f}%)")
print(f"  Imbalance Ratio:      {label_counts[0]/label_counts[1]:.2f}:1")

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Pie chart
colors = ['#2ecc71', '#e74c3c']
axes[0].pie(label_counts, labels=['No Failure (0)', 'Failure (1)'], 
            autopct='%1.1f%%', colors=colors, explode=[0, 0.05],
            shadow=True, startangle=90)
axes[0].set_title('Class Distribution', fontsize=14)

# Bar chart
sns.barplot(x=['No Failure (0)', 'Failure (1)'], y=label_counts.values, 
            palette=colors, ax=axes[1])
axes[1].set_ylabel('Count')
axes[1].set_title('Class Counts', fontsize=14)
for i, v in enumerate(label_counts.values):
    axes[1].text(i, v + 200, f'{v:,}', ha='center', fontsize=11)

plt.tight_layout()
plt.show()

print("\n⚠️ Dataset is IMBALANCED - Will apply SMOTE later")
# Out:
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\141708934.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['No Failure (0)', 'Failure (1)'], y=label_counts.values,
# Target Variable Distribution:
#   Class 0 (No Failure): 27,024 (68.84%)
#   Class 1 (Failure):    12,235 (31.16%)
#   Imbalance Ratio:      2.21:1
# ⚠️ Dataset is IMBALANCED - Will apply SMOTE later

# %% [markdown]
# ## 2.5 Categorical Features Analysis

# %%
cat_cols = ['Service Type', 'Service Name', 'Type', 'Status', 'Month']

print("Unique Values per Categorical Column:")
for col in cat_cols:
    if col in df_raw.columns:
        print(f"  {col}: {df_raw[col].nunique()} unique values")
# Out:
# Unique Values per Categorical Column:
#   Service Type: 76 unique values
#   Service Name: 110 unique values
#   Type: 2 unique values
#   Status: 4 unique values
#   Month: 10 unique values

# %%
# Distribution of key categorical features
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Type
if 'Type' in df_raw.columns:
    type_counts = df_raw['Type'].value_counts().head(10)
    sns.barplot(x=type_counts.values, y=type_counts.index, ax=axes[0,0], palette='viridis')
    axes[0,0].set_title('Top 10 Types', fontsize=12)
    axes[0,0].set_xlabel('Count')

# Status
if 'Status' in df_raw.columns:
    status_counts = df_raw['Status'].value_counts()
    sns.barplot(x=status_counts.values, y=status_counts.index, ax=axes[0,1], palette='coolwarm')
    axes[0,1].set_title('Status Distribution', fontsize=12)
    axes[0,1].set_xlabel('Count')

# Month
if 'Month' in df_raw.columns:
    month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    month_counts = df_raw['Month'].value_counts().reindex(month_order)
    sns.barplot(x=month_counts.index, y=month_counts.values, ax=axes[1,0], palette='Blues_d')
    axes[1,0].set_title('Records by Month', fontsize=12)
    axes[1,0].set_ylabel('Count')
    axes[1,0].tick_params(axis='x', rotation=45)

# Failure rate by Month
if 'Month' in df_raw.columns:
    failure_by_month = df_raw.groupby('Month')['label'].mean().reindex(month_order) * 100
    sns.barplot(x=failure_by_month.index, y=failure_by_month.values, ax=axes[1,1], palette='Reds_d')
    axes[1,1].set_title('Failure Rate by Month (%)', fontsize=12)
    axes[1,1].set_ylabel('Failure Rate (%)')
    axes[1,1].tick_params(axis='x', rotation=45)
    axes[1,1].axhline(y=df_raw['label'].mean()*100, color='red', linestyle='--', label='Overall Avg')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\3021889299.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=type_counts.values, y=type_counts.index, ax=axes[0,0], palette='viridis')
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\3021889299.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=status_counts.values, y=status_counts.index, ax=axes[0,1], palette='coolwarm')
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\3021889299.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=month_counts.index, y=month_counts.values, ax=axes[1,0], palette='Blues_d')
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\3021889299.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=failure_by_month.index, y=failure_by_month.values, ax=axes[1,1], palette='Reds_d')

# %% [markdown]
# ## 2.6 Numerical Features Analysis

# %%
# SLA analysis
if 'SLA (minutes)' in df_raw.columns:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    # Distribution
    df_raw['SLA (minutes)'].dropna().hist(bins=50, ax=axes[0], color='steelblue', edgecolor='black')
    axes[0].set_title('SLA Distribution', fontsize=12)
    axes[0].set_xlabel('SLA (minutes)')
    
    # SLA by failure
    sns.boxplot(data=df_raw, x='label', y='SLA (minutes)', ax=axes[1], palette=['#2ecc71', '#e74c3c'])
    axes[1].set_title('SLA by Failure Status', fontsize=12)
    axes[1].set_xticklabels(['No Failure', 'Failure'])
    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\3225085810.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_raw, x='label', y='SLA (minutes)', ax=axes[1], palette=['#2ecc71', '#e74c3c'])
# C:\Users\Mahesa\AppData\Local\Temp\ipykernel_26756\3225085810.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(['No Failure', 'Failure'])

# %% [markdown]
# ---
# # Part 3: Data Preprocessing & Cleaning

# %% [markdown]
# ## 3.1 Initial Cleaning

# %%
df = df_raw.copy()
print(f"Original shape: {df.shape}")

# Drop NO column (just an ID)
if 'NO' in df.columns:
    df = df.drop('NO', axis=1)
    print("Dropped 'NO' column")

print(f"Shape after dropping ID: {df.shape}")
# Out:
# Original shape: (39259, 11)
# Dropped 'NO' column
# Shape after dropping ID: (39259, 10)

# %% [markdown]
# ## 3.2 Handle Missing Values

# %%
print("Handling missing values...")

# Fill categorical with mode
for col in ['Service Type', 'Service Name']:
    if col in df.columns:
        mode_val = df[col].mode()[0]
        missing_count = df[col].isnull().sum()
        df[col] = df[col].fillna(mode_val)
        print(f"  {col}: Filled {missing_count} missing with mode '{mode_val}'")

# Fill numerical with median
if 'SLA (minutes)' in df.columns:
    median_val = df['SLA (minutes)'].median()
    missing_count = df['SLA (minutes)'].isnull().sum()
    df['SLA (minutes)'] = df['SLA (minutes)'].fillna(median_val)
    print(f"  SLA (minutes): Filled {missing_count} missing with median {median_val}")

print(f"\nRemaining missing values: {df.isnull().sum().sum()}")
# Out:
# Handling missing values...
#   Service Type: Filled 1512 missing with mode 'Inbound'
#   Service Name: Filled 1399 missing with mode 'Inbound Contact Center'
#   SLA (minutes): Filled 5580 missing with median 210.0
#
# Remaining missing values: 0

# %% [markdown]
# ## 3.3 Parse Datetime & Create Time Features

# %%
# Parse Timestamp
if 'Timestamp' in df.columns:
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
    
    # Extract time features
    df['Hour'] = df['Timestamp'].dt.hour
    df['DayOfWeek'] = df['Timestamp'].dt.dayofweek  # 0=Monday
    df['IsWeekend'] = (df['DayOfWeek'] >= 5).astype(int)
    
    print("Created time features: Hour, DayOfWeek, IsWeekend")

# Parse Resolved Time
if 'Resolved Time' in df.columns:
    df['Resolved Time'] = pd.to_datetime(df['Resolved Time'], errors='coerce')

df.head()
# Out:
# Created time features: Hour, DayOfWeek, IsWeekend
#             Timestamp Service Type            Service Name         Type  \
# 0 2024-01-01 08:13:45      Inbound  Inbound Contact Center  Restoration
# 1 2024-01-10 15:06:49            -                       -  Restoration
# 2 2024-01-05 06:11:00            -                       -  Restoration
# 3 2024-01-10 14:19:44            -                       -  Restoration
# 4 2024-01-10 14:02:29   Sosiomedio              Sosiomedio  Restoration
#
#    Status  SLA (minutes)       Resolved Time Resolved Duration (minutes)  \
# 0  Closed           45.0 2024-01-01 08:48:06                       33,12
# 1  Closed           90.0 2024-01-11 16:10:11                       12,33
# 2  Closed          210.0 2024-01-05 06:54:47                       34,30
# 3  Closed          210.0 2024-01-10 16:13:57                       15,73
# 4  Closed          210.0 2024-01-10 16:14:56                       26,33
#
#   Month  label  Hour  DayOfWeek  IsWeekend
# 0   Jan      1     8          0          0
# 1   Jan      1    15          2          0
# 2   Jan      0     6          4          0
# 3   Jan      0    14          2          0
# 4   Jan      0    14          2          0

# %% [markdown]
# ## 3.4 Parse Resolved Duration

# %%
# Handle Resolved Duration
if 'Resolved Duration (minutes)' in df.columns:
    # Convert to string first to handle formatting
    duration_str = df['Resolved Duration (minutes)'].astype(str)
    
    # Remove dots (thousands separators) and replace commas with dots (decimal separators)
    duration_cleaned = duration_str.str.replace('.', '', regex=False).str.replace(',', '.', regex=False)
    
    # Convert to numeric
    df['Resolved Duration (minutes)'] = pd.to_numeric(duration_cleaned, errors='coerce')
    
    # Replace negative values with NaN (they're invalid for duration)
    df.loc[df['Resolved Duration (minutes)'] < 0, 'Resolved Duration (minutes)'] = np.nan
    
    # Fill NaN (including former negative values) with median of valid values
    valid_values = df['Resolved Duration (minutes)'].dropna()
    median_val = valid_values.median()
    missing_count = df['Resolved Duration (minutes)'].isnull().sum()
    df['Resolved Duration (minutes)'] = df['Resolved Duration (minutes)'].fillna(median_val)
    
    print(f"Resolved Duration stats:")
    print(f"  Filled {missing_count} missing/invalid values with median: {median_val:.2f}")
    print(df['Resolved Duration (minutes)'].describe())
# Out:
# Resolved Duration stats:
#   Filled 132 missing/invalid values with median: 23.78
# count    39259.000000
# mean       146.410002
# std       1180.460453
# min          0.000000
# 25%          7.875000
# 50%         23.780000
# 75%         59.930000
# max      40716.380000
# Name: Resolved Duration (minutes), dtype: float64

# %%
# Diagnostic: Verify the conversion worked correctly
print("=" * 60)
print("RESOLVED DURATION CONVERSION DIAGNOSTIC")
print("=" * 60)

# Show some original values from CSV
print("\nSample original values from CSV (before conversion):")
sample_raw = df_raw['Resolved Duration (minutes)'].head(10)
for idx, val in sample_raw.items():
    print(f"  Row {idx}: '{val}'")

# Show converted values
print("\nSample converted values (after conversion):")
sample_converted = df['Resolved Duration (minutes)'].head(10)
for idx, val in sample_converted.items():
    print(f"  Row {idx}: {val:.2f}")

# Check for any zeros that might indicate conversion failure
zero_count = (df['Resolved Duration (minutes)'] == 0).sum()
total_count = len(df['Resolved Duration (minutes)'])
print(f"\nZero values: {zero_count} out of {total_count} ({zero_count/total_count*100:.2f}%)")

# Show value range
print(f"\nValue range:")
print(f"  Min:    {df['Resolved Duration (minutes)'].min():.2f}")
print(f"  Max:    {df['Resolved Duration (minutes)'].max():.2f}")
print(f"  Mean:   {df['Resolved Duration (minutes)'].mean():.2f}")
print(f"  Median: {df['Resolved Duration (minutes)'].median():.2f}")

if df['Resolved Duration (minutes)'].mean() > 1:
    print("\n✅ SUCCESS: Values are properly converted!")
else:
    print("\n⚠️ WARNING: Values might not be converted correctly!")
# Out:
# ============================================================
# RESOLVED DURATION CONVERSION DIAGNOSTIC
# ============================================================
#
# Sample original values from CSV (before conversion):
#   Row 0: '33,12'
#   Row 1: '12,33'
#   Row 2: '34,30'
#   Row 3: '15,73'
#   Row 4: '26,33'
#   Row 5: '10,42'
#   Row 6: '0,50'
#   Row 7: '8,92'
#   Row 8: '15,73'
#   Row 9: '14,32'
#
# Sample converted values (after conversion):
#   Row 0: 33.12
#   Row 1: 12.33
#   Row 2: 34.30
#   Row 3: 15.73
#   Row 4: 26.33
#   Row 5: 10.42
#   Row 6: 0.50
#   Row 7: 8.92
#   Row 8: 15.73
#   Row 9: 14.32
#
# Zero values: 26 out of 39259 (0.07%)
#
# Value range:
#   Min:    0.00
#   Max:    40716.38
#   Mean:   146.41
#   Median: 23.78
#
# ✅ SUCCESS: Values are properly converted!

# %% [markdown]
# ## 3.5 Encode Categorical Variables

# %%
# Label encode categorical columns
encoders = {}
cat_cols_to_encode = ['Service Type', 'Service Name', 'Type', 'Status', 'Month']

for col in cat_cols_to_encode:
    if col in df.columns:
        le = LabelEncoder()
        df[f'{col}_encoded'] = le.fit_transform(df[col].astype(str))
        encoders[col] = le
        print(f"Encoded {col}: {len(le.classes_)} classes")

print(f"\nNew shape: {df.shape}")
# Out:
# Encoded Service Type: 76 classes
# Encoded Service Name: 110 classes
# Encoded Type: 2 classes
# Encoded Status: 4 classes
# Encoded Month: 10 classes
#
# New shape: (39259, 18)

# %% [markdown]
# ## 3.6 Select Features for Model

# %%
# Select numerical features for the model
feature_cols = [
    'SLA (minutes)',
    'Resolved Duration (minutes)',
    'Hour',
    'DayOfWeek',
    'IsWeekend',
    'Service Type_encoded',
    'Service Name_encoded',
    'Type_encoded',
    'Status_encoded',
    'Month_encoded'
]

# Filter only existing columns
feature_cols = [col for col in feature_cols if col in df.columns]
print(f"Selected {len(feature_cols)} features: {feature_cols}")

# Create final dataset
df_features = df[feature_cols + ['label']].copy()

# Sort by timestamp for proper sequence creation
if 'Timestamp' in df.columns:
    df_features = df.sort_values('Timestamp')[feature_cols + ['label']].copy()

print(f"\nFinal dataset shape: {df_features.shape}")
df_features.head()
# Out:
# Selected 10 features: ['SLA (minutes)', 'Resolved Duration (minutes)', 'Hour', 'DayOfWeek', 'IsWeekend', 'Service Type_encoded', 'Service Name_encoded', 'Type_encoded', 'Status_encoded', 'Month_encoded']
#
# Final dataset shape: (39259, 11)
#       SLA (minutes)  Resolved Duration (minutes)  Hour  DayOfWeek  IsWeekend  \
# 76            240.0                        44.23    23          6          1
# 1512          210.0                        55.10     1          0          0
# 1621          210.0                        48.55     2          0          0
# 1615           60.0                        43.43     5          0          0
# 1622          360.0                        69.53     5          0          0
#
#       Service Type_encoded  Service Name_encoded  Type_encoded  \
# 76                      59                   106             1
# 1512                    29                    33             1
# 1621                    60                    97             1
# 1615                    32                    59             1
# 1622                    29                     0             1
#
#       Status_encoded  Month_encoded  label
# 76                 1              3      1
# 1512               1              3      1
# 1621               1              3      1
# 1615               1              3      1
# 1622               1              3      0

# %% [markdown]
# ## 3.7 Scale Features

# %%
scaler = StandardScaler()

X = df_features[feature_cols].values
y = df_features['label'].values

X_scaled = scaler.fit_transform(X)

print(f"X shape: {X_scaled.shape}")
print(f"y shape: {y.shape}")
print(f"\nScaled feature statistics:")
print(f"  Mean: {X_scaled.mean():.4f}")
print(f"  Std:  {X_scaled.std():.4f}")
# Out:
# X shape: (39259, 10)
# y shape: (39259,)
#
# Scaled feature statistics:
#   Mean: 0.0000
#   Std:  1.0000

# %% [markdown]
# ## 3.8 Save Processed Dataset

# %%
# Create DataFrame with scaled features
df_processed = pd.DataFrame(X_scaled, columns=feature_cols)
df_processed['label'] = y

# Save to CSV
df_processed.to_csv(PROCESSED_FILE, index=False)
print(f"✅ Processed dataset saved to: {PROCESSED_FILE}")
print(f"   Shape: {df_processed.shape}")
df_processed.head()
# Out:
# ✅ Processed dataset saved to: c:\Users\Mahesa\OneDrive\ITB\Coding\Work\Infomedia\predictive-maintenance\notebooks\..\data\processed_dataset.csv
#    Shape: (39259, 11)
#    SLA (minutes)  Resolved Duration (minutes)      Hour  DayOfWeek  IsWeekend  \
# 0      -0.410984                    -0.086561  2.605204   2.134105   2.852060
# 1      -0.412422                    -0.077352 -2.673843  -1.337392  -0.350624
# 2      -0.412422                    -0.082901 -2.433887  -1.337392  -0.350624
# 3      -0.419614                    -0.087238 -1.714017  -1.337392  -0.350624
# 4      -0.405231                    -0.065128 -1.714017  -1.337392  -0.350624
#
#    Service Type_encoded  Service Name_encoded  Type_encoded  Status_encoded  \
# 0              1.554235              2.070033      1.034234       -1.073262
# 1             -0.175003             -0.150366      1.034234       -1.073262
# 2              1.611877              1.796285      1.034234       -1.073262
# 3             -0.002079              0.640461      1.034234       -1.073262
# 4             -0.175003             -1.154108      1.034234       -1.073262
#
#    Month_encoded  label
# 0      -0.546109      1
# 1      -0.546109      1
# 2      -0.546109      1
# 3      -0.546109      1
# 4      -0.546109      0

# %% [markdown]
# ---
# # Part 4: Create Sequences for LSTM

# %% [markdown]
# ## 4.1 Define Sequence Creation Function

# %%
# Sequence parameters
SEQUENCE_LENGTH = 28

def create_sequences(X, y, seq_length):
    """Create sequences for LSTM input."""
    X_seq, y_seq = [], []
    
    for i in range(len(X) - seq_length):
        X_seq.append(X[i:i + seq_length])
        y_seq.append(y[i + seq_length])  # Predict next step
    
    return np.array(X_seq), np.array(y_seq)

print(f"✅ Sequence creation function defined (SEQUENCE_LENGTH={SEQUENCE_LENGTH})")
print("   Will be used after train/test split to avoid data leakage")
# Out:
# ✅ Sequence creation function defined (SEQUENCE_LENGTH=28)
#    Will be used after train/test split to avoid data leakage

# %% [markdown]
# ---
# # Part 5: Train/Validation Split (Before SMOTE)

# %%
VAL_SPLIT = 0.3
RANDOM_STATE = 42

# 1. Tentukan titik potong (misal 80% train, 20% val)
split_idx = int(len(X_scaled) * (1 - VAL_SPLIT))

# 2. Potong tanpa diacak
X_train = X_scaled[:split_idx]
y_train = y[:split_idx]
X_val = X_scaled[split_idx:]
y_val = y[split_idx:]

print(f"Train/Val Split ({int((1-VAL_SPLIT)*100)}/{int(VAL_SPLIT*100)}) - BEFORE SMOTE:")
print(f"  Training:   {len(X_train):,} samples")
print(f"  Validation: {len(X_val):,} samples")
print(f"\nTrain class distribution (imbalanced):")
print(f"  Class 0: {np.sum(y_train == 0):,} ({np.sum(y_train == 0)/len(y_train)*100:.1f}%)")
print(f"  Class 1: {np.sum(y_train == 1):,} ({np.sum(y_train == 1)/len(y_train)*100:.1f}%)")
print(f"\nVal class distribution (imbalanced - kept original):")
print(f"  Class 0: {np.sum(y_val == 0):,} ({np.sum(y_val == 0)/len(y_val)*100:.1f}%)")
print(f"  Class 1: {np.sum(y_val == 1):,} ({np.sum(y_val == 1)/len(y_val)*100:.1f}%)")
# Out:
# Train/Val Split (70/30) - BEFORE SMOTE:
#   Training:   27,481 samples
#   Validation: 11,778 samples
#
# Train class distribution (imbalanced):
#   Class 0: 19,328 (70.3%)
#   Class 1: 8,153 (29.7%)
#
# Val class distribution (imbalanced - kept original):
#   Class 0: 7,696 (65.3%)
#   Class 1: 4,082 (34.7%)

# %%
# Create sequences AFTER split, BEFORE SMOTE
print("Creating sequences from train/val splits...")

X_train_seq, y_train_seq = create_sequences(X_train, y_train, SEQUENCE_LENGTH)
X_val_seq, y_val_seq = create_sequences(X_val, y_val, SEQUENCE_LENGTH)

print(f"\n✅ Sequences created:")
print(f"  Training sequences:   {X_train_seq.shape} -> {len(y_train_seq):,} samples")
print(f"  Validation sequences: {X_val_seq.shape} -> {len(y_val_seq):,} samples")
print(f"\nTrain sequence class distribution (before SMOTE):")
print(f"  Class 0: {np.sum(y_train_seq == 0):,} ({np.sum(y_train_seq == 0)/len(y_train_seq)*100:.1f}%)")
print(f"  Class 1: {np.sum(y_train_seq == 1):,} ({np.sum(y_train_seq == 1)/len(y_train_seq)*100:.1f}%)")
# Out:
# Creating sequences from train/val splits...
#
# ✅ Sequences created:
#   Training sequences:   (27453, 28, 10) -> 27,453 samples
#   Validation sequences: (11750, 28, 10) -> 11,750 samples
#
# Train sequence class distribution (before SMOTE):
#   Class 0: 19,318 (70.4%)
#   Class 1: 8,135 (29.6%)

# %% [markdown]
# ---
# # Part 5.5: Create Sequences (After Split, Before SMOTE)

# %% [markdown]
# ---
# # Part 6: Apply SMOTE (Only on Training Set)

# %%
# # Apply SMOTE on sequences (flatten -> SMOTE -> reshape)
# print("⚠️ Applying SMOTE on training sequences (not validation)")
# print(f"\nBefore SMOTE (Training Sequences):")
# print(f"  Shape: {X_train_seq.shape}")
# print(f"  Class 0: {np.sum(y_train_seq == 0):,}")
# print(f"  Class 1: {np.sum(y_train_seq == 1):,}")
# print(f"  Ratio:   {np.sum(y_train_seq == 0) / np.sum(y_train_seq == 1):.2f}:1")

# # Step 1: Flatten 3D sequences to 2D for SMOTE
# # Shape: (samples, timesteps, features) -> (samples, timesteps * features)
# nsamples, nsteps, nfeatures = X_train_seq.shape
# X_train_flattened = X_train_seq.reshape((nsamples, nsteps * nfeatures))
# print(f"\nFlattened for SMOTE: {X_train_flattened.shape}")

# # Step 2: Apply SMOTE on flattened sequences
# smote = SMOTE(random_state=42)
# X_resampled_flat, y_train_resampled = smote.fit_resample(X_train_flattened, y_train_seq)

# # Step 3: Reshape back to 3D for LSTM
# # Shape: (new_samples, timesteps * features) -> (new_samples, timesteps, features)
# X_train_seq_resampled = X_resampled_flat.reshape((X_resampled_flat.shape[0], nsteps, nfeatures))

# print(f"\nAfter SMOTE (Training Sequences):")
# print(f"  Shape: {X_train_seq_resampled.shape}")
# print(f"  Class 0: {np.sum(y_train_resampled == 0):,}")
# print(f"  Class 1: {np.sum(y_train_resampled == 1):,}")
# print(f"  Ratio:   {np.sum(y_train_resampled == 0) / np.sum(y_train_resampled == 1):.2f}:1")
# print(f"  Total:   {len(y_train_seq):,} → {len(y_train_resampled):,} (+{len(y_train_resampled) - len(y_train_seq):,})")

# print(f"\n✅ Validation sequences remain unchanged (original distribution)")
# print(f"   Validation shape: {X_val_seq.shape}")
# print(f"   Validation samples: {len(y_val_seq):,}")

# %% [markdown]
# ### OPTION: NO SMOTE

# %%
# Create training data without SMOTE
X_train_seq_resampled, y_train_resampled = X_train_seq, y_train_seq

# %%
# Visualize before vs after SMOTE (Training Sequences)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Before SMOTE (Training)
before_counts = [np.sum(y_train_seq == 0), np.sum(y_train_seq == 1)]
axes[0].bar(['No Failure', 'Failure'], before_counts, color=['#2ecc71', '#e74c3c'])
axes[0].set_title('Training Sequences - Before SMOTE', fontsize=14)
axes[0].set_ylabel('Count')
for i, v in enumerate(before_counts):
    axes[0].text(i, v + 200, f'{v:,}', ha='center')

# After SMOTE (Training)
after_counts = [np.sum(y_train_resampled == 0), np.sum(y_train_resampled == 1)]
axes[1].bar(['No Failure', 'Failure'], after_counts, color=['#2ecc71', '#e74c3c'])
axes[1].set_title('Training Sequences - After SMOTE', fontsize=14)
axes[1].set_ylabel('Count')
for i, v in enumerate(after_counts):
    axes[1].text(i, v + 200, f'{v:,}', ha='center')

plt.tight_layout()
plt.show()

print(f"\n📊 SMOTE applied on complete sequences (not individual data points)")
print(f"📊 Validation sequences keep original imbalance for realistic evaluation")
# Out:
# 📊 SMOTE applied on complete sequences (not individual data points)
# 📊 Validation sequences keep original imbalance for realistic evaluation

# %% [markdown]
# ---
# # Part 7: Final Dataset Summary

# %%
# Final datasets ready for training
print("=" * 60)
print("FINAL DATASET SUMMARY")
print("=" * 60)

print(f"\n📊 Training Set (SMOTE-balanced sequences):")
print(f"   X_train shape: {X_train_seq_resampled.shape}")
print(f"   y_train shape: {y_train_resampled.shape}")
print(f"   Class 0: {np.sum(y_train_resampled == 0):,} (balanced)")
print(f"   Class 1: {np.sum(y_train_resampled == 1):,} (balanced)")

print(f"\n📊 Validation Set (original imbalanced sequences):")
print(f"   X_val shape:   {X_val_seq.shape}")
print(f"   y_val shape:   {y_val_seq.shape}")
print(f"   Class 0: {np.sum(y_val_seq == 0):,} ({np.sum(y_val_seq == 0)/len(y_val_seq)*100:.1f}%)")
print(f"   Class 1: {np.sum(y_val_seq == 1):,} ({np.sum(y_val_seq == 1)/len(y_val_seq)*100:.1f}%)")

print(f"\n✅ Ready for LSTM training")
print("=" * 60)
# Out:
# ============================================================
# FINAL DATASET SUMMARY
# ============================================================
#
# 📊 Training Set (SMOTE-balanced sequences):
#    X_train shape: (31379, 28, 10)
#    y_train shape: (31379,)
#    Class 0: 21,863 (balanced)
#    Class 1: 9,516 (balanced)
#
# 📊 Validation Set (original imbalanced sequences):
#    X_val shape:   (7824, 28, 10)
#    y_val shape:   (7824,)
#    Class 0: 5,130 (65.6%)
#    Class 1: 2,694 (34.4%)
#
# ✅ Ready for LSTM training
# ============================================================

# %% [markdown]
# ## 7.1 Save Sequences

# %%
# Create preprocessed directory if not exists
os.makedirs(PREPROCESSED_DIR, exist_ok=True)

# Save sequences
np.save(os.path.join(PREPROCESSED_DIR, 'X_train_sequences_smote.npy'), X_train_seq_resampled)
np.save(os.path.join(PREPROCESSED_DIR, 'y_train_sequences_smote.npy'), y_train_resampled)
np.save(os.path.join(PREPROCESSED_DIR, 'X_val_sequences.npy'), X_val_seq)
np.save(os.path.join(PREPROCESSED_DIR, 'y_val_sequences.npy'), y_val_seq)

print(f"✅ Sequences saved to: {PREPROCESSED_DIR}")
print(f"   X_train_sequences_smote.npy: {X_train_seq_resampled.shape}")
print(f"   y_train_sequences_smote.npy: {y_train_resampled.shape}")
print(f"   X_val_sequences.npy:         {X_val_seq.shape}")
print(f"   y_val_sequences.npy:         {y_val_seq.shape}")
# Out:
# ✅ Sequences saved to: c:\Users\Mahesa\OneDrive\ITB\Coding\Work\Infomedia\predictive-maintenance\notebooks\..\data\preprocessed
#    X_train_sequences_smote.npy: (31379, 28, 10)
#    y_train_sequences_smote.npy: (31379,)
#    X_val_sequences.npy:         (7824, 28, 10)
#    y_val_sequences.npy:         (7824,)

# %%
# Part 8: Model Training

# %%
# Import model
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'src'))
from model.lstm_cupy_optimized import LSTMModelGPUOptimized, GPU_AVAILABLE

print(f"GPU Available: {GPU_AVAILABLE}")
# Out:
# GPU Available: True

# %%
# Hyperparameters
HIDDEN_SIZE = 128        
EPOCHS = 150             
LEARNING_RATE = 0.001    
BATCH_SIZE = 256
PATIENCE = 10            
LAMBDA_L2 = 0.0001        

print("Hyperparameters:")
print(f"  Hidden Size:   {HIDDEN_SIZE}")
print(f"  Epochs:        {EPOCHS}")
print(f"  Learning Rate: {LEARNING_RATE}")
print(f"  Batch Size:    {BATCH_SIZE}")
print(f"  Patience:      {PATIENCE}")
print(f"  Lambda L2:     {LAMBDA_L2}")
# Out:
# Hyperparameters:
#   Hidden Size:   128
#   Epochs:        150
#   Learning Rate: 0.001
#   Batch Size:    256
#   Patience:      10
#   Lambda L2:     0.0001

# %%
# Initialize model
input_size = X_train_seq_resampled.shape[2]
seq_len = X_train_seq_resampled.shape[1]

print(f"Model Architecture:")
print(f"  Input size:      {input_size}")
print(f"  Sequence length: {seq_len}")
print(f"  Hidden size:     {HIDDEN_SIZE}")

model = LSTMModelGPUOptimized(input_size=input_size, hidden_size=HIDDEN_SIZE)
print(f"\n✅ Model initialized! Type: {type(model).__name__}")
# Out:
# Model Architecture:
#   Input size:      10
#   Sequence length: 28
#   Hidden size:     128
#
# ✅ Model initialized! Type: LSTMModelGPUOptimized

# %%
# Train
print("Starting training...\n")

history = model.train(
    X_train_seq_resampled, y_train_resampled,
    X_val_seq, y_val_seq,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    lr=LEARNING_RATE,
    print_every=1,
    patience=PATIENCE,
    lambda_l2=LAMBDA_L2
)
# Out:
# Starting training...
#
# Training: 31379 samples, 123 batches/epoch, batch_size=256
# Validation: 7824 samples | Early stopping patience: 10
# ----------------------------------------------------------------------
# Epoch    1/150 | Train Loss: 0.6011 | Val Loss: 0.7188 | Val Acc: 0.3452 [OVERFITTING]
# Epoch    2/150 | Train Loss: 0.6005 | Val Loss: 0.7116 | Val Acc: 0.3451 [OVERFITTING]
# Epoch    3/150 | Train Loss: 0.5998 | Val Loss: 0.6884 | Val Acc: 0.3461 [UNDERFITTING]
# Epoch    4/150 | Train Loss: 0.5998 | Val Loss: 0.6781 | Val Acc: 0.3506 [UNDERFITTING]
# Epoch    5/150 | Train Loss: 0.5990 | Val Loss: 0.7032 | Val Acc: 0.3466 [OVERFITTING]
# Epoch    6/150 | Train Loss: 0.5981 | Val Loss: 0.6930 | Val Acc: 0.3464 [UNDERFITTING]
# Epoch    7/150 | Train Loss: 0.5978 | Val Loss: 0.6638 | Val Acc: 0.3560 [UNDERFITTING]
# Epoch    8/150 | Train Loss: 0.5974 | Val Loss: 0.6819 | Val Acc: 0.3514 [UNDERFITTING]
# Epoch    9/150 | Train Loss: 0.5970 | Val Loss: 0.6941 | Val Acc: 0.3515 [UNDERFITTING]
# Epoch   10/150 | Train Loss: 0.5972 | Val Loss: 0.6954 | Val Acc: 0.3479 [UNDERFITTING]
# Epoch   11/150 | Train Loss: 0.5962 | Val Loss: 0.6871 | Val Acc: 0.3492 [UNDERFITTING]
# Epoch   12/150 | Train Loss: 0.5954 | Val Loss: 0.6880 | Val Acc: 0.3577 [UNDERFITTING]
# Epoch   13/150 | Train Loss: 0.5946 | Val Loss: 0.6836 | Val Acc: 0.3540 [UNDERFITTING]
# Epoch   14/150 | Train Loss: 0.5947 | Val Loss: 0.6946 | Val Acc: 0.3556 [UNDERFITTING]
# Epoch   15/150 | Train Loss: 0.5940 | Val Loss: 0.7265 | Val Acc: 0.3479 [OVERFITTING]
# Epoch   16/150 | Train Loss: 0.5942 | Val Loss: 0.6946 | Val Acc: 0.3485 [OVERFITTING]
#
# 🛑 Early stopping triggered at epoch 17
# ----------------------------------------------------------------------
# Final - Train Loss: 0.5932 | Val Loss: 0.6840 | Val Acc: 0.3764

# %%
# Part 9: Training Visualization

# %%
epochs_range = range(1, len(history['train_loss']) + 1)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Loss
axes[0].plot(epochs_range, history['train_loss'], 'b-', label='Training Loss', linewidth=2)
axes[0].plot(epochs_range, history['val_loss'], 'r-', label='Validation Loss', linewidth=2)
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss (BCE)')
axes[0].set_title('Training vs Validation Loss', fontsize=14)
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Plot 2: Accuracy
axes[1].plot(epochs_range, history['train_acc'], 'b--', label='Training Accuracy', linewidth=2, alpha=0.7)
axes[1].plot(epochs_range, history['val_acc'], 'g-', label='Validation Accuracy', linewidth=2)
axes[1].axhline(y=0.7, color='gray', linestyle='--', linewidth=1, label='Random Baseline')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Training vs Validation Accuracy', fontsize=14)
axes[1].legend()
axes[1].grid(True, alpha=0.3)
axes[1].set_ylim([0, 1])

plt.tight_layout()
plt.savefig(os.path.join(DATA_DIR, 'training_history.png'), dpi=150)
plt.show()

# %% [markdown]
# ---
# # Part 10: Final Evaluation

# %%
# Final metrics
val_loss, val_acc = model.evaluate(X_val_seq, y_val_seq, batch_size=BATCH_SIZE)
print(f"Final Validation Loss:     {val_loss:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")
# Out:
# Final Validation Loss:     0.6638
# Final Validation Accuracy: 0.3560

# %%
# Predictions
probabilities = model.predict(X_val_seq, batch_size=BATCH_SIZE)
predictions = (probabilities >= 0.5).astype(int)

print("Classification Report:")
print(classification_report(y_val_seq, predictions, target_names=['No Failure', 'Failure']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   No Failure       0.66      0.97      0.78      5130
#      Failure       0.39      0.04      0.07      2694
#
#     accuracy                           0.65      7824
#    macro avg       0.52      0.50      0.43      7824
# weighted avg       0.57      0.65      0.54      7824

# %%
# Confusion Matrix
cm = confusion_matrix(y_val_seq, predictions)

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=[0, 1], yticks=[0, 1],
       xticklabels=['Pred: No Failure', 'Pred: Failure'],
       yticklabels=['True: No Failure', 'True: Failure'],
       title='Confusion Matrix')

thresh = cm.max() / 2.
for i in range(2):
    for j in range(2):
        ax.text(j, i, f'{cm[i, j]:,}', ha='center', va='center',
                color='white' if cm[i, j] > thresh else 'black', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10.1 Diagnosis

# %%
final_train_loss = history['train_loss'][-1]
final_val_loss = history['val_loss'][-1]
gap = final_val_loss - final_train_loss

print("=" * 60)
print("DIAGNOSIS")
print("=" * 60)
print(f"Final Training Loss:   {final_train_loss:.4f}")
print(f"Final Validation Loss: {final_val_loss:.4f}")
print(f"Gap (Val - Train):     {gap:.4f}")

if val_acc < 0.6 and gap < 0.1:
    print("\n⚠️ DIAGNOSIS: UNDERFITTING")
    print("   Suggestions: Increase hidden_size, train longer, add features")
elif gap > 0.1:
    print("\n⚠️ DIAGNOSIS: OVERFITTING")
    print("   Suggestions: Add dropout, reduce hidden_size, early stopping")
else:
    print("\n✅ Model appears well-fitted")
# Out:
# ============================================================
# DIAGNOSIS
# ============================================================
# Final Training Loss:   0.5932
# Final Validation Loss: 0.6840
# Gap (Val - Train):     0.0908
#
# ⚠️ DIAGNOSIS: UNDERFITTING
#    Suggestions: Increase hidden_size, train longer, add features

# %% [markdown]
# ---
# # Part 11: Save Results

# %%
# Save predictions
OUTPUT_FILE = os.path.join(DATA_DIR, 'predictions_gpu_optimized.csv')

results_df = pd.DataFrame({
    'actual': y_val_seq,
    'predicted': predictions,
    'probability': probabilities
})

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"✅ Predictions saved to: {OUTPUT_FILE}")
results_df.head(10)
# Out:
# ✅ Predictions saved to: c:\Users\Mahesa\OneDrive\ITB\Coding\Work\Infomedia\predictive-maintenance\notebooks\..\data\predictions_gpu_optimized.csv
#    actual  predicted  probability
# 0       0          0     0.358673
# 1       1          0     0.348386
# 2       0          0     0.312485
# 3       0          0     0.334028
# 4       0          0     0.343114
# 5       0          0     0.294313
# 6       0          0     0.282641
# 7       1          0     0.299222
# 8       1          0     0.304649
# 9       0          0     0.303961

# %%
print("=" * 60)
print("SUMMARY")
print("=" * 60)
print(f"Model:              LSTM (hidden={HIDDEN_SIZE})")
print(f"GPU:                {GPU_AVAILABLE}")
print(f"SMOTE:              Applied on sequences ✓")
print(f"Training samples:   {len(X_train_seq_resampled):,}")
print(f"Validation samples: {len(X_val_seq):,}")
print(f"Final Val Accuracy: {val_acc:.4f}")
print(f"\n⚠️ No data leakage:")
print(f"   1. Train/test split FIRST")
print(f"   2. Create sequences from original data")
print(f"   3. SMOTE on flattened sequences (training only)")
print(f"   4. Reshape back to 3D for LSTM")
print("=" * 60)
# Out:
# ============================================================
# SUMMARY
# ============================================================
# Model:              LSTM (hidden=128)
# GPU:                True
# SMOTE:              Applied on sequences ✓
# Training samples:   31,379
# Validation samples: 7,824
# Final Val Accuracy: 0.3560
#
# ⚠️ No data leakage:
#    1. Train/test split FIRST
#    2. Create sequences from original data
#    3. SMOTE on flattened sequences (training only)
#    4. Reshape back to 3D for LSTM
# ============================================================
